# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[0.99, 0.95, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1, 0.05, 0.01, 0] 
y=[0.0011, 0.0056, 0.0112, 0.0228, 0.0351, 0.0488, 0.0644, 0.0830, 0.1066, 0.1394, 0.19468, 0.2488, 0.368, 1]

plt.figure(figsize=(15, 9))

plt.plot(x, y, linewidth=4, label = r"Зависимость $\beta(\alpha)$", color = 'forestgreen')


plt.legend(loc="best", fontsize=20)
plt.xlabel(r"$\alpha$", fontsize=30)
plt.ylabel(r"$\beta$", fontsize=30)
plt.title(r"$\beta(\alpha)$", fontsize=30)
plt.xticks(fontsize=20)
plt.yticks(fontsize=25)


plt.grid(True)
